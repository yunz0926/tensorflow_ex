# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

x_train = [1, 2, 3]
y_train = [1, 2, 3]

#tf.Variable은 tensorflow의 trainable 한 변수
#Tensorflow 2.0에서는 random_* 함수들이 random.*로 변경됨
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

hypothesis = x_train * W + b

#cost / loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

#Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

#Launch the graph in a session
sess = tf.Session()

#Initializes global variables in the graph -> variable을 run 하려면 initialize가 꼭 필요
sess.run(tf.global_variables_initializer())

#Fit the line
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\mlcc\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 0 0.7939925 [0.6191245] [-0.07328296]
# 20 0.008003532 [0.9339306] [0.06077069]
# 40 0.00080334087 [0.9653068] [0.07035124]
# 60 0.0006709861 [0.9696293] [0.06822915]
# 80 0.0006088701 [0.9713129] [0.06513533]
# 100 0.0005529796 [0.9726855] [0.06208494]
# 120 0.000502223 [0.9739715] [0.0591682]
# 140 0.00045612734 [0.975195] [0.05638761]
# 160 0.0004142637 [0.97636074] [0.05373761]
# 180 0.00037624012 [0.97747165] [0.05121216]
# 200 0.00034170915 [0.97853035] [0.04880541]
# 220 0.00031034576 [0.9795392] [0.04651179]
# 240 0.0002818603 [0.980501] [0.04432593]
# 260 0.00025599077 [0.98141736] [0.04224274]
# 280 0.00023249484 [0.9822907] [0.04025748]
# ...

# %%
#Code with placeholders
#placeholder을 사용하면 값을 나중에 따로 넘겨줄 수 있음

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

a = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')
X = tf.placeholder(tf.float32, shape = [None])
Y = tf.placeholder(tf.float32, shape = [None])

hypothesis = X * W + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

#hypothesis 대신 [cost, W, b, train] 을 쓸 수 있음
for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], feed_dict = {X:[1,2,3,4,5], Y:[2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 23.363642 [0.18743546] [0.02463698]
# 20 0.10028021 [1.1997534] [0.36071935]
# 40 0.08716122 [1.1910034] [0.41033527]
# 60 0.07611855 [1.178514] [0.45550734]
# 80 0.06647487 [1.166823] [0.49771583]
# 100 0.058052987 [1.1558977] [0.5371598]
# 120 0.0506981 [1.1456878] [0.5740208]
# 140 0.044275038 [1.1361465] [0.60846764]
# 160 0.03866572 [1.1272302] [0.6406584]
# 180 0.033767078 [1.1188978] [0.670741]
# 200 0.029488996 [1.111111] [0.6988537]
# 220 0.025752965 [1.1038344] [0.725125]
# 240 0.02249028 [1.0970341] [0.74967587]
# 260 0.019640932 [1.0906793] [0.7726189]
# 280 0.017152566 [1.0847406] [0.79405934]
# 300 0.014979476 [1.0791909] [0.8140955]
# 320 0.013081677 [1.0740047] [0.83281964]
# 340 0.011424339 [1.069158] [0.8503175]
# 360 0.009976935 [1.0646288] [0.8666694]
# 380 0.00871296 [1.0603962] [0.8819502]
# 400 0.0076090745 [1.0564408] [0.8962306]
# 420 0.006645079 [1.0527446] [0.9095755]
# 440 0.005803205 [1.0492902] [0.9220465]
# 460 0.00506797 [1.0460622] [0.9337008]
# ...
