# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

x_train = [1, 2, 3]
y_train = [1, 2, 3]

#tf.Variable은 tensorflow의 trainable 한 변수
#Tensorflow 2.0에서는 random_* 함수들이 random.*로 변경됨
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

hypothesis = x_train * W + b

#cost / loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

#Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

#Launch the graph in a session
sess = tf.Session()

#Initializes global variables in the graph -> variable을 run 하려면 initialize가 꼭 필요
sess.run(tf.global_variables_initializer())

#Fit the line
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 5.5275993 [0.5392103] [-1.3992066]
# 20 0.17975317 [1.3344104] [-0.99316573]
# 40 0.11936718 [1.3923509] [-0.9140891]
# 60 0.108013354 [1.3809254] [-0.868045]
# 80 0.09809575 [1.3636909] [-0.82695615]
# 100 0.089092076 [1.3466624] [-0.7880642]
# 120 0.080914855 [1.3303764] [-0.75102544]
# 140 0.07348814 [1.3148507] [-0.7157296]
# 160 0.066743106 [1.300054] [-0.6820929]
# 180 0.060617227 [1.2859527] [-0.6500372]
# 200 0.055053502 [1.2725137] [-0.61948794]
# 220 0.050000492 [1.2597066] [-0.59037423]
# 240 0.04541124 [1.2475014] [-0.5626288]
# 260 0.0412432 [1.2358698] [-0.5361873]
# 280 0.037457746 [1.2247846] [-0.51098853]
# 300 0.034019742 [1.2142206] [-0.48697397]
# 320 0.030897245 [1.204153] [-0.46408796]
# 340 0.028061388 [1.1945586] [-0.44227752]
# 360 0.025485793 [1.1854151] [-0.4214921]
# 380 0.023146616 [1.1767013] [-0.40168354]
# 400 0.021022124 [1.168397] [-0.38280588]
# 420 0.019092647 [1.160483] [-0.36481547]
# 440 0.017340235 [1.1529408] [-0.3476705]
# 460 0.015748674 [1.1457533] [-0.33133122]
# 480 0.014303214 [1.1389034] [-0.31576]
# 500 0.012990411 [1.1323755] [-0.30092046]
# 520 0.011798096 [1.1261543] [-0.28677836]
# 540 0.010715208 [1.1202253] [-0.27330074]
# 560 0.009731737 [1.1145754] [-0.26045665]
# 580 0.008838519 [1.1091907] [-0.24821617]
# 600 0.008027286 [1.1040592] [-0.23655091]
# 620 0.0072905137 [1.0991688] [-0.22543398]
# 640 0.0066213594 [1.0945082] [-0.21483938]
# 660 0.006013625 [1.0900667] [-0.20474271]
# 680 0.0054616653 [1.0858339] [-0.19512054]
# 700 0.004960377 [1.0818] [-0.18595062]
# 720 0.0045050834 [1.0779555] [-0.17721148]
# 740 0.0040915874 [1.074292] [-0.16888312]
# 760 0.0037160462 [1.0708004] [-0.16094619]
# 780 0.0033749705 [1.0674732] [-0.1533823]
# 800 0.0030652035 [1.0643022] [-0.14617392]
# 820 0.0027838645 [1.06128] [-0.13930431]
# 840 0.0025283464 [1.0584002] [-0.13275737]
# 860 0.0022962873 [1.0556556] [-0.12651822]
# 880 0.002085517 [1.0530399] [-0.1205723]
# 900 0.0018941001 [1.0505471] [-0.1149058]
# 920 0.0017202529 [1.0481718] [-0.10950561]
# 940 0.0015623588 [1.0459079] [-0.10435926]
# 960 0.0014189653 [1.0437504] [-0.09945478]
# 980 0.0012887286 [1.0416943] [-0.09478084]
# 1000 0.0011704379 [1.0397345] [-0.09032635]
# 1020 0.0010630082 [1.0378673] [-0.08608125]
# 1040 0.00096544175 [1.0360878] [-0.08203575]
# 1060 0.0008768285 [1.0343916] [-0.07818037]
# 1080 0.0007963495 [1.0327754] [-0.07450615]
# 1100 0.0007232588 [1.0312352] [-0.07100466]
# 1120 0.0006568774 [1.0297672] [-0.06766778]
# 1140 0.0005965853 [1.0283682] [-0.06448765]
# 1160 0.00054182846 [1.027035] [-0.06145699]
# 1180 0.00049209717 [1.0257645] [-0.05856872]
# 1200 0.00044692867 [1.0245537] [-0.05581617]
# 1220 0.00040590772 [1.0233997] [-0.05319302]
# 1240 0.00036865319 [1.0223] [-0.05069315]
# 1260 0.000334817 [1.0212519] [-0.04831082]
# 1280 0.00030408823 [1.0202534] [-0.04604045]
# 1300 0.00027617486 [1.0193012] [-0.04387662]
# 1320 0.00025082636 [1.0183942] [-0.04181451]
# 1340 0.00022780382 [1.0175297] [-0.03984933]
# 1360 0.00020689383 [1.0167059] [-0.03797654]
# 1380 0.00018790593 [1.0159208] [-0.03619177]
# 1400 0.0001706597 [1.0151726] [-0.03449092]
# 1420 0.00015499372 [1.0144595] [-0.03286993]
# 1440 0.00014076808 [1.0137799] [-0.03132513]
# 1460 0.00012784761 [1.0131323] [-0.02985291]
# 1480 0.000116114 [1.0125152] [-0.02844993]
# 1500 0.00010545526 [1.011927] [-0.02711289]
# 1520 9.5777534e-05 [1.0113665] [-0.0258387]
# 1540 8.698609e-05 [1.0108323] [-0.02462437]
# 1560 7.900266e-05 [1.0103233] [-0.02346718]
# 1580 7.175138e-05 [1.0098381] [-0.0223643]
# 1600 6.5166125e-05 [1.0093757] [-0.02131326]
# 1620 5.918484e-05 [1.0089351] [-0.02031158]
# 1640 5.3751955e-05 [1.0085152] [-0.01935705]
# 1660 4.8818823e-05 [1.008115] [-0.01844733]
# 1680 4.4337707e-05 [1.0077337] [-0.01758039]
# 1700 4.0268693e-05 [1.0073702] [-0.0167542]
# 1720 3.6573314e-05 [1.0070239] [-0.01596685]
# 1740 3.3215572e-05 [1.0066937] [-0.01521647]
# 1760 3.0167204e-05 [1.0063791] [-0.01450134]
# 1780 2.739847e-05 [1.0060794] [-0.01381983]
# 1800 2.488409e-05 [1.0057937] [-0.01317037]
# 1820 2.2599612e-05 [1.0055213] [-0.01255139]
# 1840 2.0525998e-05 [1.005262] [-0.01196156]
# 1860 1.8641791e-05 [1.0050147] [-0.01139945]
# 1880 1.6931135e-05 [1.004779] [-0.01086375]
# 1900 1.537721e-05 [1.0045544] [-0.01035322]
# 1920 1.3965714e-05 [1.0043403] [-0.00986663]
# 1940 1.268362e-05 [1.0041363] [-0.00940291]
# 1960 1.1519602e-05 [1.003942] [-0.00896104]
# 1980 1.0462274e-05 [1.0037568] [-0.00853989]
# 2000 9.502287e-06 [1.0035802] [-0.00813859]

# %%
#Code with placeholders
#placeholder을 사용하면 값을 나중에 따로 넘겨줄 수 있음

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

a = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')
X = tf.placeholder(tf.float32, shape = [None])
Y = tf.placeholder(tf.float32, shape = [None])

hypothesis = X * W + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

#hypothesis 대신 [cost, W, b, train] 을 쓸 수 있음
for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], feed_dict = {X:[1,2,3,4,5], Y:[2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 11.750125 [0.39335456] [-0.39881173]
# 20 0.24305575 [1.315634] [-0.05620119]
# 40 0.21205811 [1.2989491] [0.02062346]
# 60 0.18519181 [1.2793887] [0.09131766]
# 80 0.16172943 [1.2610915] [0.1573771]
# 100 0.1412395 [1.2439923] [0.21911015]
# 120 0.12334547 [1.228013] [0.27680036]
# 140 0.10771859 [1.2130803] [0.33071235]
# 160 0.09407133 [1.1991254] [0.38109374]
# 180 0.08215327 [1.1860846] [0.42817548]
# 200 0.07174504 [1.1738977] [0.4721738]
# 220 0.06265548 [1.1625091] [0.51329064]
# 240 0.05471747 [1.1518662] [0.5517148]
# 260 0.047785137 [1.1419203] [0.58762234]
# 280 0.04173116 [1.1326258] [0.62117845]
# 300 0.036444098 [1.1239401] [0.6525369]
# 320 0.03182693 [1.1158231] [0.6818416]
# 340 0.027794689 [1.1082377] [0.70922714]
# 360 0.024273295 [1.1011492] [0.7348192]
# 380 0.021198051 [1.0945249] [0.7587351]
# 400 0.018512394 [1.0883343] [0.78108495]
# 420 0.016167019 [1.0825493] [0.8019709]
# 440 0.0141187925 [1.0771431] [0.821489]
# 460 0.012330027 [1.0720909] [0.839729]
# 480 0.010767917 [1.0673696] [0.8567743]
# 500 0.009403723 [1.0629575] [0.8727034]
# 520 0.008212328 [1.0588344] [0.88758916]
# 540 0.007171876 [1.0549812] [0.90150017]
# 560 0.0062632547 [1.0513806] [0.9145001]
# 580 0.0054697455 [1.0480155] [0.9266487]
# 600 0.004776764 [1.0448709] [0.9380017]
# 620 0.0041715736 [1.0419323] [0.94861096]
# 640 0.0036430832 [1.0391861] [0.9585254]
# 660 0.0031815295 [1.0366198] [0.96779066]
# 680 0.0027784654 [1.0342215] [0.97644925]
# 700 0.0024264469 [1.0319804] [0.98454076]
# 720 0.0021190196 [1.0298859] [0.9921024]
# 740 0.0018505512 [1.0279286] [0.9991688]
# 760 0.001616106 [1.0260996] [1.0057722]
# 780 0.0014113613 [1.0243903] [1.0119431]
# 800 0.0012325536 [1.022793] [1.0177101]
# 820 0.0010763987 [1.0213003] [1.0230992]
# 840 0.0009400244 [1.0199053] [1.0281354]
# 860 0.0008209314 [1.0186017] [1.0328418]
# 880 0.0007169315 [1.0173836] [1.0372399]
# 900 0.0006261042 [1.0162451] [1.0413501]
# 920 0.00054677867 [1.0151812] [1.045191]
# 940 0.00047750547 [1.014187] [1.0487806]
# 960 0.000417011 [1.0132579] [1.052135]
# 980 0.0003641833 [1.0123895] [1.0552696]
# 1000 0.00031803973 [1.0115781] [1.0581992]
# 1020 0.0002777438 [1.0108199] [1.0609369]
# 1040 0.00024255551 [1.0101112] [1.0634952]
# 1060 0.00021182417 [1.009449] [1.0658859]
# 1080 0.00018498611 [1.0088302] [1.0681201]
# 1100 0.00016155245 [1.0082519] [1.0702078]
# 1120 0.00014108367 [1.0077115] [1.0721589]
# 1140 0.000123211 [1.0072064] [1.0739824]
# 1160 0.00010759987 [1.0067345] [1.0756863]
# 1180 9.396543e-05 [1.0062934] [1.0772787]
# 1200 8.206399e-05 [1.0058813] [1.0787666]
# 1220 7.166681e-05 [1.0054963] [1.0801569]
# 1240 6.258927e-05 [1.0051363] [1.0814563]
# 1260 5.466005e-05 [1.0047998] [1.0826707]
# 1280 4.7735037e-05 [1.0044855] [1.0838058]
# 1300 4.1684812e-05 [1.0041918] [1.0848666]
# 1320 3.6403122e-05 [1.0039172] [1.0858577]
# 1340 3.1791562e-05 [1.0036606] [1.0867839]
# 1360 2.776305e-05 [1.003421] [1.0876495]
# 1380 2.4245954e-05 [1.0031968] [1.0884583]
# 1400 2.1174259e-05 [1.0029875] [1.0892141]
# 1420 1.8490115e-05 [1.0027918] [1.089921]
# 1440 1.6147045e-05 [1.0026089] [1.090581]
# 1460 1.4101701e-05 [1.0024381] [1.0911978]
# 1480 1.2315436e-05 [1.0022784] [1.0917742]
# 1500 1.0755725e-05 [1.0021292] [1.0923128]
# 1520 9.393463e-06 [1.0019897] [1.0928162]
# 1540 8.20356e-06 [1.0018595] [1.0932868]
# 1560 7.163487e-06 [1.0017377] [1.0937264]
# 1580 6.2565014e-06 [1.0016239] [1.0941372]
# 1600 5.463103e-06 [1.0015175] [1.0945212]
# 1620 4.771113e-06 [1.0014181] [1.09488]
# 1640 4.167177e-06 [1.0013254] [1.0952151]
# 1660 3.6397712e-06 [1.0012386] [1.0955284]
# 1680 3.1785999e-06 [1.0011575] [1.0958213]
# 1700 2.7755352e-06 [1.0010817] [1.0960947]
# 1720 2.4243577e-06 [1.0010109] [1.0963504]
# 1740 2.1171757e-06 [1.0009447] [1.0965892]
# 1760 1.8495593e-06 [1.000883] [1.0968125]
# 1780 1.6151032e-06 [1.000825] [1.0970211]
# 1800 1.4105768e-06 [1.0007712] [1.0972161]
# 1820 1.2317129e-06 [1.0007205] [1.0973985]
# 1840 1.0757485e-06 [1.0006734] [1.0975689]
# 1860 9.394422e-07 [1.0006294] [1.097728]
# 1880 8.204167e-07 [1.000588] [1.0978767]
# 1900 7.1664704e-07 [1.0005496] [1.0980157]
# 1920 6.2591926e-07 [1.0005136] [1.0981456]
# 1940 5.4662075e-07 [1.0004799] [1.098267]
# 1960 4.7751763e-07 [1.0004486] [1.0983803]
# 1980 4.171424e-07 [1.0004194] [1.0984863]
# 2000 3.6433653e-07 [1.0003918] [1.0985854]
